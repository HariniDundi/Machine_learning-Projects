# %% [markdown]
# <a href="https://colab.research.google.com/github/HariniDundi/Machine_learning-Projects/blob/main/MLWorkshop_Module_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **knn neighbour code**

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/breast_cancer_diagnosis.csv")

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'Radius_mean', 'Texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
df=df[['id', 'diagnosis', 'Radius_mean', 'Texture_mean', 'perimeter_mean','area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean','concave points_mean', 'symmetry_mean',]]

# %%
x=df.drop('diagnosis',axis=1)
y=df['diagnosis']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3,random_state = 1)

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(n_neighbors=2)
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
y_test_hat=model.predict(x_test)
Results=pd.DataFrame({'actual':y_test,'prediction':y_test_hat})
Results.head(10)
# Out:
#     actual prediction
# 421      B          B
# 47       M          B
# 292      B          B
# 186      M          M
# 414      M          B
# 132      M          B
# 161      M          M
# 197      M          M
# 245      B          B
# 453      B          B

# %%
from sklearn.metrics import confusion_matrix,recall_score,precision_score
cm=confusion_matrix(y_test,y_test_hat)
print(cm)
# Out:
# [[106   2]
#  [ 39  24]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_test_hat))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.73      0.98      0.84       108
#            M       0.92      0.38      0.54        63
#
#     accuracy                           0.76       171
#    macro avg       0.83      0.68      0.69       171
# weighted avg       0.80      0.76      0.73       171

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(n_neighbors=2)

model.fit(x_train,y_train)
y_test_hat=model.predict(x_test)
Results=pd.DataFrame({'actual':y_test,'prediction':y_test_hat})
Results.head(10)
# Out:
#     actual prediction
# 421      B          B
# 47       M          B
# 292      B          B
# 186      M          M
# 414      M          B
# 132      M          B
# 161      M          M
# 197      M          M
# 245      B          B
# 453      B          B

# %% [markdown]
# **Random classifier code starts from here**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/banknote_authentication.csv")

# %%
df.columns
# Out:
# Index(['variance', 'skew', 'kurtosis', 'entropy', 'authentic'], dtype='object')

# %%
df.columns[df.isnull().any()]
# Out:
# Index([], dtype='object')

# %%
df["authentic"].value_counts()
# Out:
# 0    762
# 1    610
# Name: authentic, dtype: int64

# %%
df.sample(n=5,random_state=55).sort_values(['variance'])
# Out:
#       variance    skew  kurtosis  entropy  authentic
# 1180  -2.21830 -1.2540    2.9986  0.36378          1
# 769   -0.89409  3.1991   -1.8219 -2.94520          1
# 1353   0.11592  3.2219   -3.4302 -2.84570          1
# 239    2.39520  9.5083   -3.1783 -3.00860          0
# 722    4.84510  8.1116   -2.9512 -1.47240          0

# %%
x=df.drop("authentic",axis=1)
y=df['authentic']

# %%
df.sample(n=5,random_state=55).sort_values(['variance'])
# Out:
#       variance    skew  kurtosis  entropy  authentic
# 1180  -2.21830 -1.2540    2.9986  0.36378          1
# 769   -0.89409  3.1991   -1.8219 -2.94520          1
# 1353   0.11592  3.2219   -3.4302 -2.84570          1
# 239    2.39520  9.5083   -3.1783 -3.00860          0
# 722    4.84510  8.1116   -2.9512 -1.47240          0

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3,random_state = 1)

# %%
from sklearn.ensemble import RandomForestClassifier
Classifier=RandomForestClassifier(random_state=0,min_samples_leaf=10)
Classifier.fit(x_train,y_train)
# Out:
# RandomForestClassifier(min_samples_leaf=10, random_state=0)

# %%
y_test_hat = Classifier.predict(x_test)
results = pd.DataFrame({'Actual':y_test})
columns=pd.DataFrame({'predicted':y_test_hat})
results=results.join(columns.set_index(results.index))
print(results)
# Out:
#       Actual  predicted
# 1240       1          1
# 703        0          0
# 821        1          1
# 1081       1          1
# 37         0          0
# ...      ...        ...
# 559        0          0
# 400        0          0
# 439        0          0
# 634        0          0
# 628        0          0
#
# [412 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_test_hat))
# Out:
# 0.9878640776699029

# %%
TN=cm[0][0]
FP=cm[0][0]
FN=cm[1][0]
TP=cm[1][1]
recall=TP/float(FN+TP)
precision=TP/float(TP+FP)
specificity=TN/float(TN+FP)
print("recall,precision,specificity",recall,precision,specificity)
# Out:
# recall,precision,specificity 0.38095238095238093 0.18461538461538463 0.5
